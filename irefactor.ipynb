# %%
### Refactor
from metatab.estimators.estimators.lgbm import MetaEnsembleEsLGBMClassifier
# Out:
# c:\Users\avagl\Desktop\pyvenv\finetunetabpfn\Lib\site-packages\hyperopt\atpe.py:19: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 ### Refactor
# ----> 2 from metatab.estimators.estimators.lgbm import MetaEnsembleEsLGBMClassifier
#
# File ~\Desktop\packages\metatab\src\metatab\__init__.py:1
# ----> 1 from metatab.ensemble.family import FamilyEnsembleEstimator
#       2 from metatab.metatab_utils.package_data import get_example_data
#       4 from metatab.estimators import (
#       5     MetaTuneRandomForestClassifier,
#       6     MetaTuneExtraTreesClassifier,
# ...
